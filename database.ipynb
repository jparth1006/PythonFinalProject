# %%
from pathlib import Path
import sqlite3
import pandas as pd

# %%
# use pathlib to get current working directory
path = Path.cwd()

# %%
def create_db(db_name, filename, table_name):
    # create a path to the data file
    file_path = path / filename

    # create a connection to the database
    conn = sqlite3.connect(db_name)
    # create a cursor
    cur = conn.cursor()

    # read in the data 
    data = pd.read_csv(file_path)
    
    # insert the data into the specified table
    data.to_sql(table_name, conn, index=False, if_exists="replace")
    
    # execute a select statement as f-string and print results to verify insertion
    rows = cur.execute(f"SELECT * FROM {table_name}").fetchall()
    print(rows)

    # commit the changes to the database
    conn.commit()
    # close the connection
    conn.close()

# %%
db_name = "Book.db"
filename = "newScrap.csv"
table_name = "books"
create_db(db_name, filename, table_name)
# Out:
# [('A Light in the Attic', 'Poetry', 'THREE', 51.77, 'In stock ', 22), ('Tipping the Velvet', 'Historical Fiction', 'ONE', 53.74, 'In stock ', 20), ('Soumission', 'Fiction', 'ONE', 50.1, 'In stock ', 20), ('Sharp Objects', 'Mystery', 'FOUR', 47.82, 'In stock ', 20), ('Sapiens: A Brief History of Humankind', 'History', 'FIVE', 54.23, 'In stock ', 20), ('The Requiem Red', 'Young Adult', 'ONE', 22.65, 'In stock ', 19), ('The Dirty Little Secrets of Getting Your Dream Job', 'Business', 'FOUR', 33.34, 'In stock ', 19), ('The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'Default', 'THREE', 17.93, 'In stock ', 19), ('The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'Default', 'FOUR', 22.6, 'In stock ', 19), ('The Black Maria', 'Poetry', 'ONE', 52.15, 'In stock ', 19), ('Starving Hearts (Triangular Trade Trilogy, #1)', 'Default', 'TWO', 13.99, 'In stock ', 19), ("Shakespeare's Sonnets", 'Poetry', 'FOUR', 20.66, 'In stock ', 19), ('Set Me Free', 'Young Adult', 'FIVE', 17.46, 'In stock ', 19), ("Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'Sequential Art', 'FIVE', 52.29, 'In stock ', 19), ('Rip it Up and Start Again', 'Music', 'FIVE', 35.02, 'In stock ', 19), ('Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'Music', 'THREE', 57.25, 'In stock ', 19), ('Olio', 'Poetry', 'ONE', 23.88, 'In stock ', 19), ('Mesaerion: The Best Science Fiction Stories 1800-1849', 'Science Fiction', 'ONE', 37.59, 'In stock ', 19), ('Libertarianism for Beginners', 'Politics', 'TWO', 51.33, 'In stock ', 19), ("It's Only the Himalayas", 'Travel', 'TWO', 45.17, 'In stock ', 19), ('In Her Wake', 'Thriller', 'ONE', 12.84, 'In stock ', 19), ('How Music Works', 'Music', 'TWO', 37.32, 'In stock ', 19), ('Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More', 'Food and Drink', 'THREE', 30.52, 'In stock ', 19), ('Chase Me (Paris Nights #2)', 'Romance', 'FIVE', 25.27, 'In stock ', 19), ('Black Dust', 'Romance', 'FIVE', 34.53, 'In stock ', 19), ('Birdsong: A Story in Pictures', 'Childrens', 'THREE', 54.64, 'In stock ', 19), ("America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana", 'Default', 'THREE', 22.5, 'In stock ', 19), ('Aladdin and His Wonderful Lamp', 'Default', 'THREE', 53.13, 'In stock ', 19), ('Worlds Elsewhere: Journeys Around Shakespeare’s Globe', 'Nonfiction', 'FIVE', 40.3, 'In stock ', 18), ('Wall and Piece', 'Art', 'FOUR', 44.18, 'In stock ', 18), ('The Four Agreements: A Practical Guide to Personal Freedom', 'Spirituality', 'FIVE', 17.66, 'In stock ', 18), ('The Five Love Languages: How to Express Heartfelt Commitment to Your Mate', 'Nonfiction', 'THREE', 31.05, 'In stock ', 18), ('The Elephant Tree', 'Thriller', 'FIVE', 23.82, 'In stock ', 18), ('The Bear and the Piano', 'Childrens', 'ONE', 36.89, 'In stock ', 18), ("Sophie's World", 'Philosophy', 'FIVE', 15.94, 'In stock ', 18), ('Penny Maybe', 'Default', 'THREE', 33.29, 'In stock ', 18), ('Maude (1883-1993):She Grew Up with the country', 'Default', 'TWO', 18.02, 'In stock ', 18), ('In a Dark, Dark Wood', 'Mystery', 'ONE', 19.63, 'In stock ', 18), ('Behind Closed Doors', 'Thriller', 'FOUR', 52.22, 'In stock ', 18), ("You can't bury them all: Poems", 'Poetry', 'TWO', 33.63, 'In stock ', 17), ('Slow States of Collapse: Poems', 'Poetry', 'THREE', 57.31, 'In stock ', 17), ('Reasons to Stay Alive', 'Nonfiction', 'TWO', 26.41, 'In stock ', 17), ('Private Paris (Private #10)', 'Fiction', 'FIVE', 47.61, 'In stock ', 17), ('#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.', 'Nonfiction', 'FIVE', 23.11, 'In stock ', 17), ('Without Borders (Wanderlove #1)', 'New Adult', 'TWO', 45.07, 'In stock ', 16), ('When We Collided', 'Contemporary', 'ONE', 31.77, 'In stock ', 16), ('We Love You, Char ...
